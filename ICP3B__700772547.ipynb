# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [Matplotlib documentation](https://matplotlib.org/3.1.1/contents.html).
#
# If you're stuck, don't forget, you can always search for a function, for example if you want to create a plot with `plt.subplots()`, search for [`plt.subplots()`](https://www.google.com/search?q=plt.subplots()).

# %%
# Import the pyplot module from matplotlib as plt and make sure
# plots appear in the notebook using '%matplotlib inline'
# Import the pyplot module
import matplotlib.pyplot as plt

# Make plots appear in the notebook
# %matplotlib inline

# %%
# Create a simple plot using plt.plot()

import matplotlib.pyplot as plt

# Example data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a simple line plot
plt.plot(x, y)

# Add a title and labels
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plot
plt.show()

# %%
# Plot a single Python list

import matplotlib.pyplot as plt

# A single Python list
y = [3, 8, 1, 10, 5]

# Plot the list
plt.plot(y)

# Add a title and labels
plt.title('Plot of a Single List')
plt.xlabel('Index')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them

# Create the lists
X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Display the lists
print("X:", X)
print("y:", y)
# Out:
# X: [1, 2, 3, 4, 5]
# y: [10, 20, 15, 25, 30]

# %%
# Plot X & y (the lists you've created)

import matplotlib.pyplot as plt

# Your data
X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Plot X vs y
plt.plot(X, y)

# Add title and labels
plt.title('Plot of X vs y')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()
import matplotlib.pyplot as plt

# Your data
X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Create figure and axes using plt.subplots()
fig, ax = plt.subplots()

# Use the axes object to plot
ax.plot(X, y)

# Add title and labels using the axes object
ax.set_title('Plot using OO method')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %%
# Create a plot using plt.subplots() and then add X & y on the axes
import matplotlib.pyplot as plt

# Your data
X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Create figure and axes
fig, ax = plt.subplots()

# Plot X & y on the axes
ax.plot(X, y)

# Add title and axis labels
ax.set_title('Plot with plt.subplots()')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Display the plot
plt.show()

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready


# Prepare data (create two lists of 5 numbers, X & y)


# Setup figure and axes using plt.subplots()


# Add data (X, y) to axes


# Customize plot by adding a title, xlabel and ylabel


# Save the plot to file using fig.savefig()

# 1. Import and get matplotlib ready
import matplotlib.pyplot as plt

# 2. Prepare data (create two lists of 5 numbers, X & y)
X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# 3. Setup figure and axes using plt.subplots()
fig, ax = plt.subplots()

# 4. Add data (X, y) to axes
ax.plot(X, y)

# 5. Customize plot by adding a title, xlabel and ylabel
ax.set_title('My First OO Method Plot')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# 6. Save the plot to file using fig.savefig()
fig.savefig('my_plot.png')  # This will save the plot as 'my_plot.png' in your working directory

# Show the plot in the notebook
plt.show()

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
# Import NumPy as np
# Import NumPy as np
import numpy as np

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X

import numpy as np

# Create an array of 100 evenly spaced numbers between 0 and 100
X = np.linspace(0, 100, 100)

# Display the array
print(X)
# Out:
# [  0.           1.01010101   2.02020202   3.03030303   4.04040404
#    5.05050505   6.06060606   7.07070707   8.08080808   9.09090909
#   10.1010101   11.11111111  12.12121212  13.13131313  14.14141414
#   15.15151515  16.16161616  17.17171717  18.18181818  19.19191919
#   20.2020202   21.21212121  22.22222222  23.23232323  24.24242424
#   25.25252525  26.26262626  27.27272727  28.28282828  29.29292929
#   30.3030303   31.31313131  32.32323232  33.33333333  34.34343434
#   35.35353535  36.36363636  37.37373737  38.38383838  39.39393939
#   40.4040404   41.41414141  42.42424242  43.43434343  44.44444444
#   45.45454545  46.46464646  47.47474747  48.48484848  49.49494949
#   50.50505051  51.51515152  52.52525253  53.53535354  54.54545455
#   55.55555556  56.56565657  57.57575758  58.58585859  59.5959596
#   60.60606061  61.61616162  62.62626263  63.63636364  64.64646465
#   65.65656566  66.66666667  67.67676768  68.68686869  69.6969697
#   70.70707071  71.71717172  72.72727273  73.73737374  74.74747475
#   75.75757576  76.76767677  77.77777778  78.78787879  79.7979798
#   80.80808081  81.81818182  82.82828283  83.83838384  84.84848485
#   85.85858586  86.86868687  87.87878788  88.88888889  89.8989899
#   90.90909091  91.91919192  92.92929293  93.93939394  94.94949495
#   95.95959596  96.96969697  97.97979798  98.98989899 100.        ]

# %%
# Create a plot using plt.subplots() and plot X versus X^2 (X squared)

import numpy as np
import matplotlib.pyplot as plt

# Create X: 100 evenly spaced numbers between 0 and 100
X = np.linspace(0, 100, 100)

# Calculate Y = X squared
Y = X ** 2

# Create figure and axes
fig, ax = plt.subplots()

# Plot X vs X squared
ax.plot(X, Y)

# Customize the plot
ax.set_title('Plot of X vs X Squared')
ax.set_xlabel('X')
ax.set_ylabel('X Squared')

# Show the plot
plt.show()

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))
import numpy as np
import matplotlib.pyplot as plt

# Create X: 100 evenly spaced numbers between 0 and 5 (smaller range for better scale)
X = np.linspace(0, 5, 100)

# Compute exponential of X
Y = np.exp(X)

# Create figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(X, Y)

# Customize the plot
ax.set_title('Scatter Plot of X vs exp(X)')
ax.set_xlabel('X')
ax.set_ylabel('exp(X)')

# Show the plot
plt.show()

# %%
# Create a scatter plot of X versus np.sin(X)

import numpy as np
import matplotlib.pyplot as plt

# Create X: 100 evenly spaced numbers between 0 and 10 for a nice sine wave
X = np.linspace(0, 10, 100)

# Compute Y = sin(X)
Y = np.sin(X)

# Create figure and axes
fig, ax = plt.subplots()

# Create scatter plot
ax.scatter(X, Y)

# Customize the plot
ax.set_title('Scatter Plot of X vs sin(X)')
ax.set_xlabel('X')
ax.set_ylabel('sin(X)')

# Show the plot
plt.show()

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with
# The keys of the dictionary should be the food name and the values their price

# Create a dictionary of favorite foods and their prices
favorite_foods = {
    'Pizza': 12,
    'Sushi': 18,
    'Burger': 10
}

# Display the dictionary
print(favorite_foods)
# Out:
# {'Pizza': 12, 'Sushi': 18, 'Burger': 10}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary


# Add a title, xlabel and ylabel to the plot

import matplotlib.pyplot as plt

# Your data
favorite_foods = {
    'Pizza': 12,
    'Sushi': 18,
    'Burger': 10
}

# Extract keys and values
foods = list(favorite_foods.keys())
prices = list(favorite_foods.values())

# Create figure and axes
fig, ax = plt.subplots()

# Create bar plot
ax.bar(foods, prices)

# Add title and labels
ax.set_title('Prices of My Favourite Foods')
ax.set_xlabel('Food')
ax.set_ylabel('Price ($)')

# Show the plot
plt.show()

# %%
# Make the same plot as above, except this time make the bars go horizontal

import matplotlib.pyplot as plt

# Your data
favorite_foods = {
    'Pizza': 12,
    'Sushi': 18,
    'Burger': 10
}

# Extract keys and values
foods = list(favorite_foods.keys())
prices = list(favorite_foods.values())

# Create figure and axes
fig, ax = plt.subplots()

# Create horizontal bar plot
ax.barh(foods, prices)

# Add title and labels
ax.set_title('Prices of My Favourite Foods (Horizontal)')
ax.set_xlabel('Price ($)')
ax.set_ylabel('Food')

# Show the plot
plt.show()

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X


# Create a histogram plot of X

import numpy as np
import matplotlib.pyplot as plt

# Create random NumPy array of 1000 normally distributed numbers
X = np.random.randn(1000)  # Mean = 0, SD = 1 by default

# Create figure and axes
fig, ax = plt.subplots()

# Create histogram
ax.hist(X, bins=30, edgecolor='black')  # bins=30 for smoother look

# Customize the plot
ax.set_title('Histogram of Normally Distributed Data')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create a NumPy array of 1000 random numbers and save it to X


# Create a histogram plot of X

import numpy as np
import matplotlib.pyplot as plt

# Create a NumPy array of 1000 random numbers (uniform distribution)
X = np.random.rand(1000)

# Create figure and axes
fig, ax = plt.subplots()

# Create histogram
ax.hist(X, bins=30, edgecolor='black')

# Customize the plot
ax.set_title('Histogram of 1000 Random Numbers')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
import matplotlib.pyplot as plt

# Create empty subplots: 2 rows, 2 columns
fig, axes = plt.subplots(nrows=2, ncols=2)

# Add a main title to the whole figure (optional)
fig.suptitle('2x2 Subplots Example')

# Display the empty subplots
plt.show()

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)


# Plot X versus X/2 on the top left axes


# Plot a scatter plot of 10 random numbers on each axis on the top right subplot


# Plot a bar graph of the favourite food keys and values on the bottom left subplot


# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot

import numpy as np
import matplotlib.pyplot as plt

# Prepare data
X = np.linspace(0, 10, 100)  # For line plot

# For scatter plot
x_scatter = np.random.rand(10)
y_scatter = np.random.rand(10)

# For bar plot
favorite_foods = {
    'Pizza': 12,
    'Sushi': 18,
    'Burger': 10
}
foods = list(favorite_foods.keys())
prices = list(favorite_foods.values())

# For histogram
normal_data = np.random.randn(1000)

# Create 2x2 subplots with figsize (10, 5)
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))
fig.suptitle('2x2 Subplots Example', fontsize=16)

# Top left: Line plot (X vs X/2)
axes[0, 0].plot(X, X/2)
axes[0, 0].set_title('Line Plot: X vs X/2')

# Top right: Scatter plot of random numbers
axes[0, 1].scatter(x_scatter, y_scatter)
axes[0, 1].set_title('Scatter Plot: Random Points')

# Bottom left: Bar plot of favourite foods
axes[1, 0].bar(foods, prices)
axes[1, 0].set_title('Bar Plot: Favourite Foods')

# Bottom right: Histogram of normal distribution
axes[1, 1].hist(normal_data, bins=30, edgecolor='black')
axes[1, 1].set_title('Histogram: Normal Dist.')

# Adjust layout
plt.tight_layout()
fig.subplots_adjust(top=0.88)  # Leave space for main title

# Show the plot
plt.show()

# %% [markdown]
# Now we've seen how to plot with Matplotlib and data directly.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
# Import pandas as pd
# Import pandas as pd
import pandas as pd

# %%
import pandas as pd

# Use the full absolute path
car_sales = pd.read_csv('/Users/akanksharasaputhra/Downloads/Code_Help 2/car-sales (1).csv')

# View the DataFrame
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Try to plot the 'Price' column using the plot() function
# Check the first few rows of the 'Price' column
print(car_sales['Price'].head())

# Check the data type
print(car_sales['Price'].dtype)
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# Name: Price, dtype: object
# object

# %%
# Remove $ and , then convert to float (handles decimals)
car_sales['Price'] = car_sales['Price'].replace(r'[$,]', '', regex=True).astype(float)

# Confirm the type
print(car_sales['Price'].dtype)

# Plot it
import matplotlib.pyplot as plt

car_sales['Price'].plot()

plt.title('Car Prices')
plt.xlabel('Index')
plt.ylabel('Price ($)')
plt.show()
# Out:
# float64

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %% [markdown]
# Here 'Price' column is still stored as text (object dtype) because it contains symbols like $ and ,.
# So we can’t plot it as numeric data until we clean and convert it!

# %% [markdown]
# Here’s how to fix it properly:
# We’ll:
# 1) Clean 'Price' so it’s numeric
# 2) Add a new column 'Total Sales' using .cumsum()
# 3) Add a 'Sale Date' column using pd.date_range()

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
# ✅ Safely remove symbols, final two digits, and convert to int
car_sales['Price'] = (
    car_sales['Price']
    .astype(str)                          # Ensure it's a string
    .replace(r'[$,]', '', regex=True)     # Remove $ and commas
    .str[:-2]                              # Remove final two characters
    .astype(int)                           # Convert to int
)

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column


# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)

# View the car_sales DataFrame

import pandas as pd

# Assuming you already have the cleaned 'Price' column:
# car_sales['Price'] = car_sales['Price'].replace(r'[$,]', '', regex=True).str[:-2].astype(int)

# 1️⃣ Add 'Total Sales' column (cumulative sum of 'Price')
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# 2️⃣ Add 'Sale Date' column (successive dates starting today)
car_sales['Sale Date'] = pd.date_range(start=pd.Timestamp.today().normalize(), periods=len(car_sales))

# 3️⃣ View the updated DataFrame
print(car_sales.head())
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2025-07-14
# 1   Honda    Red          87899      4   5000         9000 2025-07-15
# 2  Toyota   Blue          32549      3   7000        16000 2025-07-16
# 3     BMW  Black          11179      5  22000        38000 2025-07-17
# 4  Nissan  White         213095      4   3500        41500 2025-07-18

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column

import matplotlib.pyplot as plt

# Plot 'Sale Date' vs 'Total Sales'
car_sales.plot(x='Sale Date', y='Total Sales', title='Total Sales Over Time')

# Add axis labels for context
plt.xlabel('Sale Date')
plt.ylabel('Total Sales ($)')

# Show the plot
plt.show()

# %%
# Convert the 'Price' column to the integers

# If not done yet: remove symbols and last two digits, then convert


# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function

import pandas as pd

# Example: reload CSV if needed
# car_sales = pd.read_csv('/Users/akanksharasaputhra/Downloads/Code_Help 2/car-sales (1).csv')

# ✅ Make sure it's a string, remove $, commas, and last 2 chars, then convert
car_sales['Price'] = (
    car_sales['Price']
    .astype(str)  # ensure it's string
    .replace(r'[$,]', '', regex=True)
    .str[:-2]  # drop final 2 characters
    .astype(int)  # convert to int
)

# Confirm
print(car_sales['Price'].head())
print(car_sales['Price'].dtype)
# Out:
# 0     4
# 1     5
# 2     7
# 3    22
# 4     3
# Name: Price, dtype: int64
# int64

# %%
import matplotlib.pyplot as plt

# Create scatter plot
car_sales.plot(kind='scatter', x='Odometer (KM)', y='Price', title='Price vs Odometer (KM)')

plt.xlabel('Odometer (KM)')
plt.ylabel('Price ($)')
plt.show()

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to X


# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']


# Create a bar graph of the DataFrame

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Create a NumPy array of random numbers with shape (10, 4)
X = np.random.rand(10, 4)

# 2️⃣ Turn the NumPy array into a DataFrame with columns ['a', 'b', 'c', 'd']
df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])

# View the DataFrame
print(df.head())

# 3️⃣ Create a bar graph of the DataFrame
df.plot(kind='bar', figsize=(10, 6), title='Bar Graph of Random Data')

plt.xlabel('Index')
plt.ylabel('Value')
plt.show()
# Out:
#           a         b         c         d
# 0  0.572297  0.260818  0.690562  0.917183
# 1  0.253510  0.866490  0.631085  0.053999
# 2  0.012620  0.844147  0.384536  0.944237
# 3  0.348165  0.724396  0.795872  0.028091
# 4  0.318946  0.443880  0.261417  0.398929

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame
import matplotlib.pyplot as plt

# Create bar graph of 'Make' vs 'Odometer (KM)'
car_sales.plot(kind='bar', x='Make', y='Odometer (KM)', figsize=(10, 6), title='Odometer (KM) by Car Make')

# Add axis labels
plt.xlabel('Make')
plt.ylabel('Odometer (KM)')

# Show the plot
plt.show()

# %%
# Create a histogram of the 'Odometer (KM)' column

import matplotlib.pyplot as plt

# Create histogram of 'Odometer (KM)'
car_sales['Odometer (KM)'].plot(kind='hist', bins=30, figsize=(10, 6), title='Distribution of Odometer (KM)')

# Add axis labels
plt.xlabel('Odometer (KM)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create a histogram of the 'Price' column with 20 bins

import matplotlib.pyplot as plt

# Create histogram of 'Price' with 20 bins
car_sales['Price'].plot(kind='hist', bins=20, figsize=(10, 6), title='Distribution of Car Prices')

# Add axis labels
plt.xlabel('Price ($)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# Now we've seen a few examples of plotting directly from DataFrames using the `car_sales` dataset.
#
# Let's try using a different dataset.

# %%
# Import "../data/heart-disease.csv" and save it to the variable "heart_disease"
import pandas as pd

# Import the CSV file and save to variable
heart_disease = pd.read_csv('/Users/akanksharasaputhra/Downloads/Code_Help 2/heart-disease (1).csv')

# View the first few rows to confirm
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# View the first 10 rows of the heart_disease DataFrame
# View the first 10 rows
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
# Create a histogram of the "age" column with 50 bins
import matplotlib.pyplot as plt

# Create histogram of the "age" column with 50 bins
heart_disease['age'].plot(kind='hist', bins=50, figsize=(10, 6), title='Age Distribution')

# Add axis labels
plt.xlabel('Age')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Call plot.hist() on the heart_disease DataFrame and toggle the
# "subplots" parameter to True

import matplotlib.pyplot as plt

# Create histograms for all numeric columns in separate subplots
heart_disease.plot.hist(subplots=True, figsize=(12, 10), bins=30, title='Heart Disease Data - Histograms')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# That plot looks pretty squished. Let's change the figsize.

# %%
# Call the same line of code from above except change the "figsize" parameter
# to be (10, 30)
import matplotlib.pyplot as plt

# Create histograms for all numeric columns with subplots and larger figsize
heart_disease.plot.hist(subplots=True, figsize=(10, 30), bins=30, title='Heart Disease Data - Histograms')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's try comparing two variables versus the target variable.
#
# More specifially we'll see how age and cholesterol combined effect the target in **patients over 50 years old**.
#
# For this next challenge, we're going to be replicating the plot1:

# %%
# Replicate the above plot in whichever way you see fit

# Note: The method below is only one way of doing it, yours might be
# slightly different

# Create DataFrame with patients over 50 years old


# Create the plot


# Plot the data


# Customize the plot


# Add a meanline


import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Create DataFrame with patients over 50 years old
over_50 = heart_disease[heart_disease['age'] > 50]

# 2️⃣ Create the plot and figure
fig, ax = plt.subplots(figsize=(10, 6))

# 3️⃣ Plot the data: scatter plot with color by target
scatter = ax.scatter(
    over_50['age'],
    over_50['chol'],
    c=over_50['target'],  # color by target
    cmap='bwr'  # blue-white-red color map
)

# 4️⃣ Customize the plot
ax.set_title('Heart Disease: Age vs Cholesterol (Patients Over 50)')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')

# Add color bar for target
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Heart Disease (0 = No, 1 = Yes)')

# 5️⃣ Add a mean line for cholesterol
chol_mean = over_50['chol'].mean()
ax.axhline(chol_mean, linestyle='--', color='grey', label=f'Mean Cholesterol ({chol_mean:.0f})')

# Add legend for mean line
ax.legend()

plt.show()

# %% [markdown]
# Now you've created a plot of two different variables, let's change the style.

# %%
# Check what styles are available under plt
import matplotlib.pyplot as plt

# Check available styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Change the style to use "seaborn-whitegrid"
import matplotlib.pyplot as plt

print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
import matplotlib.pyplot as plt

# Check what’s available
print(plt.style.available)

# ✅ Use the correct one (pick the one that matches your list)
plt.style.use('seaborn-v0_8-whitegrid')  # or 'seaborn-whitegrid' if that's what you see

# Now any plot you make will use that style
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Now the style has been changed, we'll replot the same figure from above and see what it looks like.
#
# If you've changed the style correctly, it should look like plot2

# %%
# Reproduce the same figure as above with the "seaborn-whitegrid" style

# Create the plot


# Plot the data


# Customize the plot


# Add a meanline

import matplotlib.pyplot as plt

# ✅ 1) Set the style
plt.style.use('seaborn-v0_8-whitegrid')  # or 'seaborn-whitegrid' if that's your version

# ✅ 2) Filter patients over 50
over_50 = heart_disease[heart_disease['age'] > 50]

# ✅ 3) Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# ✅ 4) Plot the data
scatter = ax.scatter(
    over_50['age'],
    over_50['chol'],
    c=over_50['target'],
    cmap='bwr'
)

# ✅ 5) Customize the plot
ax.set_title('Heart Disease: Age vs Cholesterol (Patients Over 50)')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')

# Add color bar for 'target'
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Heart Disease (0 = No, 1 = Yes)')

# ✅ 6) Add a meanline for cholesterol
chol_mean = over_50['chol'].mean()
ax.axhline(chol_mean, linestyle='--', color='grey', label=f'Mean Cholesterol ({chol_mean:.0f})')

# Add legend
ax.legend()

# ✅ Show the plot
plt.show()

# %% [markdown]
# Wonderful, you've changed the style of the plots and the figure is looking different but the dots aren't a very good colour.
#
# Let's change the `cmap` parameter of `scatter()` as well as the `color` parameter of `axhline()` to fix it.
#
# Completing this step correctly should result in a figure which looks like plot3

# %%
# Replot the same figure as above except change the "cmap" parameter
# of scatter() to "winter"
# Also change the "color" parameter of axhline() to "red"

# Create the plot


# Plot the data


# Customize the plot


# Add a meanline

import matplotlib.pyplot as plt

# Use the desired style
plt.style.use('seaborn-v0_8-whitegrid')  # or 'seaborn-whitegrid'

# Filter patients over 50
over_50 = heart_disease[heart_disease['age'] > 50]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data with cmap='winter'
scatter = ax.scatter(
    over_50['age'],
    over_50['chol'],
    c=over_50['target'],
    cmap='winter'  # New colormap
)

# Customize the plot
ax.set_title('Heart Disease: Age vs Cholesterol (Patients Over 50)')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')

# Add color bar for target
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Heart Disease (0 = No, 1 = Yes)')

# Add meanline with color='red'
chol_mean = over_50['chol'].mean()
ax.axhline(chol_mean, linestyle='--', color='red', label=f'Mean Cholesterol ({chol_mean:.0f})')

# Add legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# Beautiful! Now our figure has an upgraded color scheme let's save it to file.

# %%
# Save the current figure using savefig(), the file name can be anything you want
import matplotlib.pyplot as plt

# Your plot code here...
# (Replot with the figure and axes)

# ✅ Save the figure
fig.savefig('heart_disease_age_chol_plot3.png')

# Show the plot
plt.show()

# %%
# Reset the figure by calling plt.subplots()
import matplotlib.pyplot as plt

# Reset the figure and axes
fig, ax = plt.subplots()

# Now fig and ax are empty and ready for your next plot!
